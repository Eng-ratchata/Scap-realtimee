# %%
from tvdatafeed import TvDatafeed, Interval

tv = TvDatafeed()  # หรือใส่ user/pass ถ้าต้องการ
data = tv.get_hist(symbol='AAPL', exchange='NASDAQ', interval=Interval.in_daily, n_bars=100)
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#       3 tv = TvDatafeed()  # หรือใส่ user/pass ถ้าต้องการ
#       4 data = tv.get_hist(symbol='AAPL', exchange='NASDAQ', interval=Interval.in_daily, n_bars=100)
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
# !pip install tvdatafeed

# %%
# !which python
# Out:
# 'which' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !where python
# Out:
# C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe
# C:\Users\Eng\AppData\Local\Programs\Python\Python313\python.exe
# C:\Users\Eng\AppData\Local\Microsoft\WindowsApps\python.exe
