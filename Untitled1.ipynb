# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
# !{sys.executable} -m pip install tvdatafeed --upgrade
# Out:
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !{sys.executable} -m pip install tvdatafeed --upgrade
# Out:
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !{sys.executable} script.py
# Out:
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import sys
!"{sys.executable}" script.py
# Out:
# C:\Users\Eng\AppData\Local\Programs\Python\Python310\python.exe: can't open file 'C:\\Users\\Eng\\Desktop\\Scap-realtime\\script.py': [Errno 2] No such file or directory

# %%
import subprocess
import sys

subprocess.run([sys.executable, "script.py"])
# Out:
# CompletedProcess(args=['C:\\Users\\Eng\\Desktop\\Scap-realtime\\myenv\\Scripts\\python.exe', 'script.py'], returncode=2)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe

# %%
import subprocess

subprocess.run([
    r"C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe", 
    "my_script.py"
])
# Out:
# CompletedProcess(args=['C:\\Users\\Eng\\Desktop\\Scap-realtime\\myenv\\Scripts\\python.exe', 'my_script.py'], returncode=2)

# %%
# !pip show tvdatafeed
# Out:
# Name: tvdatafeed
# Version: 2.1.0
# Summary: TradingView historical data downloader
# Home-page: https://github.com/rongardF/tvdatafeed/
# Author: @StreamAlpha
# Author-email:
# License: MIT License
# Location: c:\users\eng\desktop\scap-realtime\myenv\lib\site-packages
# Requires: pandas, requests, setuptools, websocket-client
# Required-by:

# %%
# !{sys.executable} -m pip install tvdatafeed

# %%
! "C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe" -m pip install tvdatafeed

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
# !{sys.executable} -m pip install selenium
# Out:
# ...
#   Using cached selenium-4.31.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached selenium-4.31.0-py3-none-any.whl (9.4 MB)
# Using cached trio-0.30.0-py3-none-any.whl (499 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# ...

# %%
# !{sys.executable} -m pip install chromedriver-autoinstaller

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
# !{sys.executable} -m pip install tvdatafeed

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe

# %%
import sys
# !{sys.executable} -m pip install tvdatafeed

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe

# %%
cmd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 cmd
#
# NameError: name 'cmd' is not defined

# %%
import sys
# !{sys.executable} -m pip install tvdatafeed

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
# !{sys.executable} -m pip install tvdatafeed

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
# !{sys.executable} -m pip install --upgrade --force-reinstall tvdatafeed
# Out:
# ERROR: Could not find a version that satisfies the requirement tvdatafeed (from versions: none)
# ERROR: No matching distribution found for tvdatafeed

# %%
from tvdatafeed import tvdatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from tvdatafeed import tvdatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
# !{sys.executable} -m pip install tvdatafeed

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Eng\Desktop\Scap-realtime\myenv\Scripts\python.exe

# %%
import sys
# !{sys.executable} -m pip install tvdatafeed --upgrade --force-reinstall
# Out:
# ERROR: Could not find a version that satisfies the requirement tvdatafeed (from versions: none)
# ERROR: No matching distribution found for tvdatafeed

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/StreamAlpha/tvdatafeed.git
# Out:
# ...
#   Cloning https://github.com/StreamAlpha/tvdatafeed.git to c:\users\eng\appdata\local\temp\pip-req-build-yfh32ehs
#   Running command git clone --filter=blob:none --quiet https://github.com/StreamAlpha/tvdatafeed.git 'C:\Users\Eng\AppData\Local\Temp\pip-req-build-yfh32ehs'
#   remote: Repository not found.
#   fatal: repository 'https://github.com/StreamAlpha/tvdatafeed.git/' not found
#   error: subprocess-exited-with-error
#
#   git clone --filter=blob:none --quiet https://github.com/StreamAlpha/tvdatafeed.git 'C:\Users\Eng\AppData\Local\Temp\pip-req-build-yfh32ehs' did not run successfully.
#   exit code: 128
#
#   See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# git clone --filter=blob:none --quiet https://github.com/StreamAlpha/tvdatafeed.git 'C:\Users\Eng\AppData\Local\Temp\pip-req-build-yfh32ehs' did not run successfully.
# exit code: 128
#
# See above for output.
#
# ...

# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/rongardF/tvdatafeed.git
# Out:
# ...
#   Cloning https://github.com/rongardF/tvdatafeed.git to c:\users\eng\appdata\local\temp\pip-req-build-ykoyn79o
#   Resolved https://github.com/rongardF/tvdatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed.git 'C:\Users\Eng\AppData\Local\Temp\pip-req-build-ykoyn79o'

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
import sys
print(sys.version)
# Out:
# 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'

# %%
from tvdatafeed import TvDatafeed, Interval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tvdatafeed import TvDatafeed, Interval
#
# ModuleNotFoundError: No module named 'tvdatafeed'
